# %% [markdown]
# <h1>Ques1</h1>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to ~/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteQGV4ZV/imdb_reviews-train.tfrecord*...…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteQGV4ZV/imdb_reviews-test.tfrecord*...:…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteQGV4ZV/imdb_reviews-unsupervised.tfrec…
# Dataset imdb_reviews downloaded and prepared to ~/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
train_data, test_data = imdb['train'], imdb['test']
buffer_size = 25000
batch_size = 32
train_dataset = train_data.shuffle(buffer_size).batch(batch_size)
test_dataset = test_data.batch(batch_size)
training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
# Create Text Vectorization Layer
vocab_size = 1000
encoder = tf.keras.layers.TextVectorization(max_tokens=vocab_size)
encoder.adapt(train_dataset.map(lambda text,label:text))

# %%
embedding_dim = 64
max_length = 120
model = tf.keras.Sequential([
    encoder,
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

# Training the model
num_epochs = 30
history = model.fit(train_dataset, epochs=num_epochs, validation_data=(test_dataset))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  text_vectorization (TextVec  (None, None)             0
#  torization)
#
#  embedding (Embedding)       (None, None, 64)          64000
#
#  bidirectional (Bidirectiona  (None, 64)               18816
#  l)
#
#  dense (Dense)               (None, 6)                 390
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 83,213
# Trainable params: 83,213
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 782/782 [==============================] - 63s 69ms/step - loss: 0.5727 - accuracy: 0.6876 - val_loss: 0.4572 - val_accuracy: 0.7956
# Epoch 2/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.4191 - accuracy: 0.8183 - val_loss: 0.3887 - val_accuracy: 0.8292
# Epoch 3/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.3402 - accuracy: 0.8600 - val_loss: 0.3227 - val_accuracy: 0.8610
# Epoch 4/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.3054 - accuracy: 0.8763 - val_loss: 0.3105 - val_accuracy: 0.8675
# Epoch 5/30
# 782/782 [==============================] - 53s 67ms/step - loss: 0.2882 - accuracy: 0.8836 - val_loss: 0.3195 - val_accuracy: 0.8663
# Epoch 6/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.2754 - accuracy: 0.8902 - val_loss: 0.3037 - val_accuracy: 0.8714
# Epoch 7/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.2637 - accuracy: 0.8938 - val_loss: 0.3065 - val_accuracy: 0.8725
# Epoch 8/30
# 782/782 [==============================] - 51s 65ms/step - loss: 0.2502 - accuracy: 0.9002 - val_loss: 0.3115 - val_accuracy: 0.8715
# Epoch 9/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.2337 - accuracy: 0.9086 - val_loss: 0.3160 - val_accuracy: 0.8676
# Epoch 10/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.2197 - accuracy: 0.9144 - val_loss: 0.3240 - val_accuracy: 0.8690
# Epoch 11/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.2053 - accuracy: 0.9220 - val_loss: 0.3428 - val_accuracy: 0.8639
# Epoch 12/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.1912 - accuracy: 0.9265 - val_loss: 0.3836 - val_accuracy: 0.8613
# Epoch 13/30
# 782/782 [==============================] - 54s 68ms/step - loss: 0.1800 - accuracy: 0.9322 - val_loss: 0.3624 - val_accuracy: 0.8659
# Epoch 14/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.1624 - accuracy: 0.9404 - val_loss: 0.3645 - val_accuracy: 0.8647
# Epoch 15/30
# 782/782 [==============================] - 53s 68ms/step - loss: 0.1490 - accuracy: 0.9455 - val_loss: 0.4036 - val_accuracy: 0.8615
# Epoch 16/30
# 782/782 [==============================] - 51s 65ms/step - loss: 0.1360 - accuracy: 0.9520 - val_loss: 0.4068 - val_accuracy: 0.8614
# Epoch 17/30
# 782/782 [==============================] - 51s 64ms/step - loss: 0.1277 - accuracy: 0.9554 - val_loss: 0.4310 - val_accuracy: 0.8596
# Epoch 18/30
# 782/782 [==============================] - 56s 71ms/step - loss: 0.1158 - accuracy: 0.9615 - val_loss: 0.4287 - val_accuracy: 0.8575
# Epoch 19/30
# 782/782 [==============================] - 51s 64ms/step - loss: 0.1118 - accuracy: 0.9617 - val_loss: 0.4469 - val_accuracy: 0.8575
# Epoch 20/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.0990 - accuracy: 0.9670 - val_loss: 0.4997 - val_accuracy: 0.8602
# Epoch 21/30
# 782/782 [==============================] - 51s 65ms/step - loss: 0.0960 - accuracy: 0.9682 - val_loss: 0.4887 - val_accuracy: 0.8550
# Epoch 22/30
# 782/782 [==============================] - 52s 65ms/step - loss: 0.0823 - accuracy: 0.9741 - val_loss: 0.5434 - val_accuracy: 0.8534
# Epoch 23/30
# 782/782 [==============================] - 51s 65ms/step - loss: 0.0745 - accuracy: 0.9772 - val_loss: 0.5800 - val_accuracy: 0.8455
# Epoch 24/30
# 782/782 [==============================] - 51s 65ms/step - loss: 0.0762 - accuracy: 0.9760 - val_loss: 0.5533 - val_accuracy: 0.8546
# Epoch 25/30
# 782/782 [==============================] - 53s 67ms/step - loss: 0.0685 - accuracy: 0.9791 - val_loss: 0.5723 - val_accuracy: 0.8517
# Epoch 26/30
# 782/782 [==============================] - 53s 67ms/step - loss: 0.0558 - accuracy: 0.9836 - val_loss: 0.6619 - val_accuracy: 0.8468
# Epoch 27/30
# 782/782 [==============================] - 52s 67ms/step - loss: 0.0520 - accuracy: 0.9838 - val_loss: 0.6918 - val_accuracy: 0.8506
# Epoch 28/30
# 782/782 [==============================] - 51s 65ms/step - loss: 0.0565 - accuracy: 0.9815 - val_loss: 0.7023 - val_accuracy: 0.8495
# Epoch 29/30
# 782/782 [==============================] - 51s 65ms/step - loss: 0.0561 - accuracy: 0.9824 - val_loss: 0.7097 - val_accuracy: 0.8508
# Epoch 30/30
# 782/782 [==============================] - 52s 66ms/step - loss: 0.0363 - accuracy: 0.9899 - val_loss: 0.7708 - val_accuracy: 0.8471

# %%
model.predict(np.array(["Movie is the best!!"]))
# Out:
# array([[0.9997043]], dtype=float32)

# %%
model.predict(['aman'])
# Out:
# array([[0.5751797]], dtype=float32)

# %% [markdown]
# <h1>que2</h1>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file("flower_photos", origin = url, untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 11s 0us/step
# 228827136/228813984 [==============================] - 11s 0us/step

# %%
data_dir
# Out:
# '/root/.keras/datasets/flower_photos'

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(data_dir,
                                            validation_split=0.2,
                                            subset='training',
                                            image_size = (180,180),
                                            seed=0,
                                            batch_size=32)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
valid_ds = tf.keras.utils.image_dataset_from_directory(data_dir,
                                            validation_split=0.2,
                                            subset='validation',
                                            image_size = (180,180),
                                            seed=0,
                                            batch_size=32)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
valid_ds = valid_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0034399498 1.0

# %%
for image_batch,labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
num_classes = 5

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=valid_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 11s 39ms/step - loss: 1.2784 - accuracy: 0.4557 - val_loss: 1.1364 - val_accuracy: 0.5368
# Epoch 2/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.9744 - accuracy: 0.6196 - val_loss: 1.0180 - val_accuracy: 0.6117
# Epoch 3/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.8082 - accuracy: 0.6843 - val_loss: 0.9363 - val_accuracy: 0.6485
# Epoch 4/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.6164 - accuracy: 0.7711 - val_loss: 0.9160 - val_accuracy: 0.6540
# Epoch 5/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.3948 - accuracy: 0.8617 - val_loss: 1.0096 - val_accuracy: 0.6717
# Epoch 6/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.2490 - accuracy: 0.9101 - val_loss: 1.1293 - val_accuracy: 0.6485
# Epoch 7/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.1199 - accuracy: 0.9636 - val_loss: 1.3387 - val_accuracy: 0.6512
# Epoch 8/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.0707 - accuracy: 0.9830 - val_loss: 1.6027 - val_accuracy: 0.6662
# Epoch 9/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.0549 - accuracy: 0.9867 - val_loss: 1.7658 - val_accuracy: 0.6499
# Epoch 10/10
# 92/92 [==============================] - 2s 24ms/step - loss: 0.0591 - accuracy: 0.9823 - val_loss: 1.4242 - val_accuracy: 0.6526

# %%
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']

loss = model.history.history['loss']
val_loss = model.history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

img = keras.preprocessing.image.load_img(
    sunflower_path, target_size=(180, 180)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg
# 122880/117948 [===============================] - 0s 0us/step
# 131072/117948 [=================================] - 0s 0us/step
# This image most likely belongs to sunflowers with a 99.95 percent confidence.
